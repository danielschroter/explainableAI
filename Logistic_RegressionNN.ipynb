# %%
import nltk
import numpy as np
import pandas as pd
from tensorflow import keras
from tensorflow.keras.layers import Dense
from sentence_transformers import SentenceTransformer

sbert_model = SentenceTransformer('bert-base-nli-mean-tokens')

# %%
def cosine(u, v):
    return np.dot(u, v) / (np.linalg.norm(u) * np.linalg.norm(v))

# %%
# You have to adjust the
df_arguments = pd.read_csv("arguments_train.csv")
df_keypoints = pd.read_csv("key_points_train.csv")
df_labels = pd.read_csv("labels_train.csv")

# %%
df_arguments
# Out:
#           arg_id                                           argument  \
# 0        arg_0_0  `people reach their limit when it comes to the...
# 1        arg_0_1  A patient should be able to decide when they h...
# 2        arg_0_2  a person has the right to end their suffering ...
# 3        arg_0_3  a person should have the dignity to choose how...
# 4        arg_0_4  a person should have the right to be able to c...
# ...          ...                                                ...
# 5578  arg_27_218  we should subsidize vocational education to en...
# 5579  arg_27_219  We should subsidize vocational education to su...
# 5580  arg_27_220  While many who graduate from universities stru...
# 5581  arg_27_221  with the rising cost of college tuition vocati...
# 5582  arg_27_222  yes, we should subsidize vocational education ...
#
#                                               topic  stance
# 0     Assisted suicide should be a criminal offence      -1
# 1     Assisted suicide should be a criminal offence      -1
# 2     Assisted suicide should be a criminal offence      -1
# 3     Assisted suicide should be a criminal offence      -1
# 4     Assisted suicide should be a criminal offence      -1
# ...                                             ...     ...
# 5578       We should subsidize vocational education       1
# 5579       We should subsidize vocational education       1
# 5580       We should subsidize vocational education       1
# 5581       We should subsidize vocational education       1
# 5582       We should subsidize vocational education       1
#
# [5583 rows x 4 columns]

# %%
df_keypoints
# Out:
#     key_point_id                                          key_point  \
# 0         kp_0_0  Assisted suicide gives dignity to the person t...
# 1         kp_0_1                 Assisted suicide reduces suffering
# 2         kp_0_2  People should have the freedom to choose to en...
# 3         kp_0_3  The terminally ill would benefit from assisted...
# 4         kp_0_4  Assisted suicide allows people to solicit some...
# ..           ...                                                ...
# 202      kp_27_3      subsidizing vocational education is expensive
# 203      kp_27_4  subsidizing vocational education promotes thos...
# 204      kp_27_5       vocational education is a good career choice
# 205      kp_27_6     vocational education better fits many students
# 206      kp_27_7  vocational education is beneficial for the ent...
#
#                                              topic  stance
# 0    Assisted suicide should be a criminal offence      -1
# 1    Assisted suicide should be a criminal offence      -1
# 2    Assisted suicide should be a criminal offence      -1
# 3    Assisted suicide should be a criminal offence      -1
# 4    Assisted suicide should be a criminal offence       1
# ..                                             ...     ...
# 202       We should subsidize vocational education      -1
# 203       We should subsidize vocational education       1
# 204       We should subsidize vocational education       1
# 205       We should subsidize vocational education       1
# 206       We should subsidize vocational education       1
#
# [207 rows x 4 columns]

# %%
df_labels
# Out:
#            arg_id key_point_id  label
# 0         arg_0_0       kp_0_0      0
# 1       arg_0_121       kp_0_4      0
# 2       arg_0_121       kp_0_5      0
# 3       arg_0_121       kp_0_6      1
# 4       arg_0_121       kp_0_7      0
# ...           ...          ...    ...
# 20630  arg_27_221      kp_27_6      0
# 20631  arg_27_221      kp_27_7      0
# 20632  arg_27_222      kp_27_4      0
# 20633  arg_27_222      kp_27_5      1
# 20634  arg_27_222      kp_27_7      0
#
# [20635 rows x 3 columns]

# %%
df_labels_ones = df_labels[df_labels["label"] == 1]
df_labels_ones
# Out:
#            arg_id key_point_id  label
# 3       arg_0_121       kp_0_6      1
# 9         arg_0_1       kp_0_2      1
# 11        arg_0_2       kp_0_1      1
# 14        arg_0_3       kp_0_2      1
# 18        arg_0_4       kp_0_2      1
# ...           ...          ...    ...
# 20604   arg_27_89      kp_27_1      1
# 20605   arg_27_90      kp_27_2      1
# 20614   arg_27_92      kp_27_3      1
# 20623  arg_27_220      kp_27_5      1
# 20633  arg_27_222      kp_27_5      1
#
# [4260 rows x 3 columns]

# %%
df_labels_zeros = df_labels[df_labels["label"] == 0]
df_labels_zeros
# Out:
#            arg_id key_point_id  label
# 0         arg_0_0       kp_0_0      0
# 1       arg_0_121       kp_0_4      0
# 2       arg_0_121       kp_0_5      0
# 4       arg_0_121       kp_0_7      0
# 5       arg_0_121       kp_0_8      0
# ...           ...          ...    ...
# 20629  arg_27_221      kp_27_4      0
# 20630  arg_27_221      kp_27_6      0
# 20631  arg_27_221      kp_27_7      0
# 20632  arg_27_222      kp_27_4      0
# 20634  arg_27_222      kp_27_7      0
#
# [16375 rows x 3 columns]

# %%
df_labels_zeros_reduced = df_labels_zeros.sample(n=4260, random_state=1)
df_labels_zeros_reduced
# Out:
#            arg_id key_point_id  label
# 1310    arg_1_157       kp_1_8      0
# 2953     arg_2_83       kp_2_5      0
# 3714     arg_3_58       kp_3_4      0
# 13003  arg_19_159      kp_19_4      0
# 11129  arg_14_109      kp_14_2      0
# ...           ...          ...    ...
# 1474    arg_1_177       kp_1_6      0
# 1703     arg_1_76       kp_1_2      0
# 4804    arg_5_198       kp_5_5      0
# 11417   arg_16_44      kp_16_1      0
# 9263    arg_13_15      kp_13_2      0
#
# [4260 rows x 3 columns]

# %%
df_labels_merged0 = np.vstack((df_labels_ones, df_labels_zeros_reduced))
#垂直合并
df_labels_merged0
# Out:
# array([['arg_0_121', 'kp_0_6', 1],
#        ['arg_0_1', 'kp_0_2', 1],
#        ['arg_0_2', 'kp_0_1', 1],
#        ...,
#        ['arg_5_198', 'kp_5_5', 0],
#        ['arg_16_44', 'kp_16_1', 0],
#        ['arg_13_15', 'kp_13_2', 0]], dtype=object)

# %%
np.random.shuffle(df_labels_merged0)
#顺序打乱
df_labels_merged = pd.DataFrame(df_labels_merged0)
#重新转化为DataFrame
df_labels_merged.columns = ["arg_id", "key_point_id", "label"]
df_labels_merged
#df_labels_merged_labels = df_labels_merged[]
#df_labels_merged_labels
# Out:
#           arg_id key_point_id label
# 0     arg_12_199      kp_12_5     1
# 1        arg_6_3       kp_6_0     1
# 2     arg_25_213      kp_25_5     0
# 3       arg_11_0      kp_11_3     1
# 4      arg_24_83      kp_24_2     1
# ...          ...          ...   ...
# 8515   arg_12_33      kp_12_1     0
# 8516    arg_3_40       kp_3_3     0
# 8517   arg_5_157       kp_5_9     0
# 8518    arg_6_36       kp_6_3     0
# 8519  arg_26_192      kp_26_5     1
#
# [8520 rows x 3 columns]

# %%
merged_dataset=df_labels_merged.merge(df_arguments, left_on="arg_id", right_on="arg_id")
# df_arguments.loc[df_arguments['arg_id'] == "arg_4_121"]
full_dataset_train=merged_dataset.merge(df_keypoints, left_on="key_point_id", right_on="key_point_id")
full_dataset_train
# Out:
#           arg_id key_point_id label  \
# 0     arg_12_199      kp_12_5     1
# 1     arg_12_181      kp_12_5     1
# 2     arg_12_190      kp_12_5     0
# 3     arg_12_163      kp_12_5     1
# 4     arg_12_219      kp_12_5     0
# ...          ...          ...   ...
# 8515  arg_17_131      kp_17_2     1
# 8516  arg_17_172      kp_17_2     0
# 8517  arg_17_164      kp_17_2     0
# 8518  arg_17_104      kp_17_2     0
# 8519  arg_17_150      kp_17_2     1
#
#                                                argument  \
# 0     the private military companies are owned by el...
# 1     private military companies should be banned be...
# 2     private miltary companies are open to abusing ...
# 3     Private military companies have their bottom l...
# 4     we should ban private military companies becau...
# ...                                                 ...
# 8515  nuclear weapons create unnecessary political t...
# 8516  there is no need for nuclear weapons anywhere ...
# 8517  The production of nuclear weapons exposes many...
# 8518  If something exists, it is impossible to ensur...
# 8519  our goal should be the abolition of nuclear we...
#
#                                                 topic_x  stance_x  \
# 0              We should ban private military companies         1
# 1              We should ban private military companies         1
# 2              We should ban private military companies         1
# 3              We should ban private military companies         1
# 4              We should ban private military companies         1
# ...                                                 ...       ...
# 8515  We should fight for the abolition of nuclear w...         1
# 8516  We should fight for the abolition of nuclear w...         1
# 8517  We should fight for the abolition of nuclear w...         1
# 8518  We should fight for the abolition of nuclear w...         1
# 8519  We should fight for the abolition of nuclear w...         1
#
#                                               key_point  \
# 0     Private military companies main interest is pr...
# 1     Private military companies main interest is pr...
# 2     Private military companies main interest is pr...
# 3     Private military companies main interest is pr...
# 4     Private military companies main interest is pr...
# ...                                                 ...
# 8515  Nuclear weapons provoke or escalate a disastro...
# 8516  Nuclear weapons provoke or escalate a disastro...
# 8517  Nuclear weapons provoke or escalate a disastro...
# 8518  Nuclear weapons provoke or escalate a disastro...
# 8519  Nuclear weapons provoke or escalate a disastro...
#
#                                                 topic_y  stance_y
# 0              We should ban private military companies         1
# 1              We should ban private military companies         1
# 2              We should ban private military companies         1
# 3              We should ban private military companies         1
# 4              We should ban private military companies         1
# ...                                                 ...       ...
# 8515  We should fight for the abolition of nuclear w...         1
# 8516  We should fight for the abolition of nuclear w...         1
# 8517  We should fight for the abolition of nuclear w...         1
# 8518  We should fight for the abolition of nuclear w...         1
# 8519  We should fight for the abolition of nuclear w...         1
#
# [8520 rows x 9 columns]

# %%
altdata_arguments = sbert_model.encode(full_dataset_train["argument"])
# altdata_arguments
altdata_keypoints = sbert_model.encode(full_dataset_train["key_point"])
# altdata_keypoints
training = np.array(np.hstack((altdata_arguments, altdata_keypoints)))
training.shape
#输出(8520, 1536)，是将8520个argument的arg和kp向量整合了（768*2）
# Out:
# (8520, 1536)

# %%
labels = np.array(full_dataset_train["label"])
labels.dtype
print(labels)
labels=np.asarray(labels).astype(np.int)
#training.dtype
#training.dtypes
# Out:
# [1 1 0 ... 0 0 1]

# %%
model = keras.Sequential()
model.add(Dense(40, activation='relu', input_dim=(1536)))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy')
model.fit(training, labels, epochs=1, verbose=1, batch_size = 1)
#model.summary()
# Out:
# 8520/8520 [==============================] - 5s 517us/step - loss: 0.6845

# %%
model.save('RegressionNNFullData.h5')

# %%
pred = model.predict(training)
pred
# Out:
# array([[0.3712124 ],
#        [0.2504996 ],
#        [0.473503  ],
#        ...,
#        [0.79017794],
#        [0.8087212 ],
#        [0.8820193 ]], dtype=float32)

# %%
labels
# Out:
# array([1, 1, 0, ..., 0, 0, 1])

# %%
pred = pred.flatten()
#转化为一维向量

res = np.vstack((pred, labels))
df_res = pd.DataFrame(res)
df_res = df_res.transpose()
df_res.columns = ["predicted", "true"]
df_res['predicted_label'] = np.where(df_res['predicted'] >= 0.5, 1, 0)
df_res['match'] = np.where(df_res['true'] == df_res['predicted_label'], 1, 0)
#新增了两列
print(df_res)
df_res['match'].sum()
accuracy = df_res['match'].sum() / df_res.shape[0]
accuracy
# Out:
#       predicted  true  predicted_label  match
# 0      0.371212   1.0                0      0
# 1      0.250500   1.0                0      0
# 2      0.473503   0.0                0      1
# 3      0.473503   1.0                0      0
# 4      0.467034   0.0                0      1
# ...         ...   ...              ...    ...
# 8515   0.852757   1.0                1      1
# 8516   0.885341   0.0                1      0
# 8517   0.790178   0.0                1      0
# 8518   0.808721   0.0                1      0
# 8519   0.882019   1.0                1      1
#
# [8520 rows x 4 columns]
# 0.6884976525821597

# %%
df_res.describe()
# Out:
#          predicted         true  predicted_label        match
# count  8520.000000  8520.000000      8520.000000  8520.000000
# mean      0.484491     0.500000         0.411268     0.688498
# std       0.247514     0.500029         0.492092     0.463135
# min       0.001333     0.000000         0.000000     0.000000
# 25%       0.305613     0.000000         0.000000     0.000000
# 50%       0.473503     0.500000         0.000000     1.000000
# 75%       0.659628     1.000000         1.000000     1.000000
# max       0.998034     1.000000         1.000000     1.000000

# %%
df_one = df_res[df_res["true"] == 1]
df_one.describe()
# Out:
#          predicted    true  predicted_label        match
# count  4260.000000  4260.0      4260.000000  4260.000000
# mean      0.606075     1.0         0.599765     0.599765
# std       0.215807     0.0         0.490003     0.490003
# min       0.021341     1.0         0.000000     0.000000
# 25%       0.473503     1.0         0.000000     0.000000
# 50%       0.589310     1.0         1.000000     1.000000
# 75%       0.790970     1.0         1.000000     1.000000
# max       0.998034     1.0         1.000000     1.000000

# %%
df_zeros = df_res[df_res["true"] == 0]
df_zeros.describe()
# Out:
#          predicted    true  predicted_label        match
# count  4260.000000  4260.0      4260.000000  4260.000000
# mean      0.362907     0.0         0.222770     0.777230
# std       0.215397     0.0         0.416154     0.416154
# min       0.001333     0.0         0.000000     0.000000
# 25%       0.177942     0.0         0.000000     1.000000
# 50%       0.371603     0.0         0.000000     1.000000
# 75%       0.473503     0.0         0.000000     1.000000
# max       0.963200     0.0         1.000000     1.000000

# %%
df_arguments_dev = pd.read_csv("arguments_dev.csv")
df_keypoints_dev = pd.read_csv("key_points_dev.csv")
df_labels_dev = pd.read_csv("labels_dev.csv")

# %%
df_labels_dev
# Out:
#           arg_id key_point_id  label
# 0      arg_4_121       kp_4_5      1
# 1      arg_4_121       kp_4_6      0
# 2      arg_4_121       kp_4_7      0
# 3      arg_4_122       kp_4_8      0
# 4      arg_4_122       kp_4_5      1
# ...          ...          ...    ...
# 3453  arg_15_226      kp_15_3      0
# 3454  arg_15_226      kp_15_4      0
# 3455  arg_15_226      kp_15_5      1
# 3456  arg_15_226      kp_15_6      0
# 3457  arg_15_226      kp_15_7      0
#
# [3458 rows x 3 columns]

# %%
df_arguments_dev
# Out:
#          arg_id                                           argument  \
# 0       arg_4_0  having a school uniform can reduce bullying as...
# 1       arg_4_1             it is a good way to instill discipline
# 2       arg_4_2  it is cheaper for parents to buy school unifor...
# 3       arg_4_3  one of the benefits of school uniforms is that...
# 4       arg_4_4  researchers found that in schools across the w...
# ..          ...                                                ...
# 927  arg_15_222  we should end it and give people that are the ...
# 928  arg_15_223   we should end it so that every persons are equal
# 929  arg_15_224  we should evaluate candidates based solely on ...
# 930  arg_15_225  we should select people based on their merit o...
# 931  arg_15_226  yes, you should have to work your way to the t...
#
#                                            topic  stance
# 0    We should abandon the use of school uniform      -1
# 1    We should abandon the use of school uniform      -1
# 2    We should abandon the use of school uniform      -1
# 3    We should abandon the use of school uniform      -1
# 4    We should abandon the use of school uniform      -1
# ..                                           ...     ...
# 927             We should end affirmative action       1
# 928             We should end affirmative action       1
# 929             We should end affirmative action       1
# 930             We should end affirmative action       1
# 931             We should end affirmative action       1
#
# [932 rows x 4 columns]

# %%
df_keypoints_dev
# Out:
#    key_point_id                                          key_point  \
# 0        kp_4_0  Children can still express themselves using ot...
# 1        kp_4_1                    School uniform reduces bullying
# 2        kp_4_2  School uniforms encourage discipline or focus ...
# 3        kp_4_3                        School uniforms saves costs
# 4        kp_4_4   School uniforms create a sense of equality/unity
# 5        kp_4_5  School uniform is harming the student's self e...
# 6        kp_4_6                      School uniforms are expensive
# 7        kp_4_7     School uniforms are often uncomfortable/sexist
# 8        kp_4_8           School uniform harms learning/creativity
# 9        kp_4_9  School uniforms increase conformity or harm in...
# 10       kp_7_0                         Gun control is ineffective
# 11       kp_7_1                           Gun ownership is a right
# 12       kp_7_2  Gun ownership is necessary for hunting/sports-...
# 13       kp_7_3             Gun ownership promotes self protection
# 14       kp_7_4                      Banning guns would save lives
# 15       kp_7_5                 Guns can fall into the wrong hands
# 16       kp_7_6                     Guns lead to accidental deaths
# 17       kp_7_7  Gun ownership allows for mass-shootings/genera...
# 18       kp_8_0        Austerity cuts access to essential services
# 19       kp_8_1                        Austerity extend recessions
# 20       kp_8_2                Austerity is unfair to the citizens
# 21       kp_8_3                  Austerity results in lower growth
# 22       kp_8_4            Austerity results in lower job creation
# 23       kp_8_5           Austerity improves the economic measures
# 24       kp_8_6            Austerity is important in the long term
# 25       kp_8_7       Austerity is important to increase stability
# 26       kp_8_8  Austerity is necessary to reduce deficits or p...
# 27       kp_8_9  Austerity regime is essential in economically ...
# 28      kp_15_0                Affirmative action boosts diversity
# 29      kp_15_1  Affirmative action is necessary to compensate ...
# 30      kp_15_2          Affirmative action reduces discrimination
# 31      kp_15_3  Affirmative action diminishes the achievements...
# 32      kp_15_4                  Affirmative action is ineffective
# 33      kp_15_5                     Affirmative action is not just
# 34      kp_15_6           Affirmative action perpetuates prejudice
# 35      kp_15_7                 Affirmative action reduces quality
#
#                                                 topic  stance
# 0         We should abandon the use of school uniform      -1
# 1         We should abandon the use of school uniform      -1
# 2         We should abandon the use of school uniform      -1
# 3         We should abandon the use of school uniform      -1
# 4         We should abandon the use of school uniform      -1
# 5         We should abandon the use of school uniform       1
# 6         We should abandon the use of school uniform       1
# 7         We should abandon the use of school uniform       1
# 8         We should abandon the use of school uniform       1
# 9         We should abandon the use of school uniform       1
# 10  We should abolish the right to keep and bear arms      -1
# 11  We should abolish the right to keep and bear arms      -1
# 12  We should abolish the right to keep and bear arms      -1
# 13  We should abolish the right to keep and bear arms      -1
# 14  We should abolish the right to keep and bear arms       1
# 15  We should abolish the right to keep and bear arms       1
# 16  We should abolish the right to keep and bear arms       1
# 17  We should abolish the right to keep and bear arms       1
# 18                We should adopt an austerity regime      -1
# 19                We should adopt an austerity regime      -1
# 20                We should adopt an austerity regime      -1
# 21                We should adopt an austerity regime      -1
# 22                We should adopt an austerity regime      -1
# 23                We should adopt an austerity regime       1
# 24                We should adopt an austerity regime       1
# 25                We should adopt an austerity regime       1
# 26                We should adopt an austerity regime       1
# 27                We should adopt an austerity regime       1
# 28                   We should end affirmative action      -1
# 29                   We should end affirmative action      -1
# 30                   We should end affirmative action      -1
# 31                   We should end affirmative action       1
# 32                   We should end affirmative action       1
# 33                   We should end affirmative action       1
# 34                   We should end affirmative action       1
# 35                   We should end affirmative action       1

# %%
merged_dataset_dev=df_labels_dev.merge(df_arguments_dev, left_on="arg_id", right_on="arg_id")
# df_arguments.loc[df_arguments['arg_id'] == "arg_4_121"]
full_dataset_dev=merged_dataset_dev.merge(df_keypoints_dev, left_on="key_point_id", right_on="key_point_id")
full_dataset_dev
# Out:
#           arg_id key_point_id  label  \
# 0      arg_4_121       kp_4_5      1
# 1      arg_4_122       kp_4_5      1
# 2      arg_4_123       kp_4_5      1
# 3      arg_4_124       kp_4_5      1
# 4      arg_4_126       kp_4_5      1
# ...          ...          ...    ...
# 3453  arg_15_218      kp_15_7      1
# 3454  arg_15_219      kp_15_7      0
# 3455  arg_15_223      kp_15_7      0
# 3456  arg_15_225      kp_15_7      0
# 3457  arg_15_226      kp_15_7      0
#
#                                                argument  \
# 0     A real education is about giving students the ...
# 1     children express themselves through the clothe...
# 2     children should be able to dress as they wish,...
# 3      children should be allowed to express themselves
# 4     freedom of expression extends to the right to ...
# ...                                                 ...
# 3453  we should end affirmative action because stude...
# 3454  we should end affirmative action because this ...
# 3455   we should end it so that every persons are equal
# 3456  we should select people based on their merit o...
# 3457  yes, you should have to work your way to the t...
#
#                                           topic_x  stance_x  \
# 0     We should abandon the use of school uniform         1
# 1     We should abandon the use of school uniform         1
# 2     We should abandon the use of school uniform         1
# 3     We should abandon the use of school uniform         1
# 4     We should abandon the use of school uniform         1
# ...                                           ...       ...
# 3453             We should end affirmative action         1
# 3454             We should end affirmative action         1
# 3455             We should end affirmative action         1
# 3456             We should end affirmative action         1
# 3457             We should end affirmative action         1
#
#                                               key_point  \
# 0     School uniform is harming the student's self e...
# 1     School uniform is harming the student's self e...
# 2     School uniform is harming the student's self e...
# 3     School uniform is harming the student's self e...
# 4     School uniform is harming the student's self e...
# ...                                                 ...
# 3453                 Affirmative action reduces quality
# 3454                 Affirmative action reduces quality
# 3455                 Affirmative action reduces quality
# 3456                 Affirmative action reduces quality
# 3457                 Affirmative action reduces quality
#
#                                           topic_y  stance_y
# 0     We should abandon the use of school uniform         1
# 1     We should abandon the use of school uniform         1
# 2     We should abandon the use of school uniform         1
# 3     We should abandon the use of school uniform         1
# 4     We should abandon the use of school uniform         1
# ...                                           ...       ...
# 3453             We should end affirmative action         1
# 3454             We should end affirmative action         1
# 3455             We should end affirmative action         1
# 3456             We should end affirmative action         1
# 3457             We should end affirmative action         1
#
# [3458 rows x 9 columns]

# %%
altdata_arguments_dev = sbert_model.encode(full_dataset_dev["argument"])
# altdata_arguments
altdata_keypoints_dev = sbert_model.encode(full_dataset_dev["key_point"])
# altdata_keypoints
dev = np.hstack((altdata_arguments_dev, altdata_keypoints_dev))
dev.shape
# Out:
# (3458, 1536)

# %%
labels_dev = np.array(full_dataset_dev["label"])

# %%
pred = model.predict(dev)
pred
# Out:
# array([[0.61408025],
#        [0.28963453],
#        [0.41223758],
#        ...,
#        [0.0833765 ],
#        [0.46371314],
#        [0.17582738]], dtype=float32)

# %%
pred = pred.flatten()

res = np.vstack((pred, labels_dev))
df_res = pd.DataFrame(res)
df_res = df_res.transpose()
df_res.columns = ["predicted", "true"]
df_res['predicted_label'] = np.where(df_res['predicted'] >= 0.5, 1, 0)
df_res['match'] = np.where(df_res['true'] == df_res['predicted_label'], 1, 0)
print(df_res)
df_res['match'].sum()
accuracy = df_res['match'].sum() / df_res.shape[0]
accuracy
# Out:
#       predicted  true  predicted_label  match
# 0      0.614080   1.0                1      1
# 1      0.289635   1.0                0      0
# 2      0.412238   1.0                0      0
# 3      0.178121   1.0                0      0
# 4      0.752372   1.0                1      1
# ...         ...   ...              ...    ...
# 3453   0.473503   1.0                0      0
# 3454   0.442855   0.0                0      1
# 3455   0.083376   0.0                0      1
# 3456   0.463713   0.0                0      1
# 3457   0.175827   0.0                0      1
#
# [3458 rows x 4 columns]
# 0.7050318102949682

# %%
df_arguments_test = pd.read_csv("arguments_test.csv")
df_keypoints_test = pd.read_csv("key_points_test.csv")
df_labels_test = pd.read_csv("labels_test.csv")

# %%
df_labels_test
# Out:
#          arg_id key_point_id  label
# 0     arg_0_112       kp_0_4      0
# 1     arg_0_112       kp_0_5      0
# 2     arg_0_112       kp_0_6      0
# 3     arg_0_112       kp_0_7      1
# 4       arg_0_0       kp_0_0      0
# ...         ...          ...    ...
# 3421  arg_1_232       kp_1_9      0
# 3422  arg_0_111       kp_0_3      0
# 3423  arg_0_111       kp_0_0      1
# 3424  arg_0_111       kp_0_1      0
# 3425  arg_0_111       kp_0_2      0
#
# [3426 rows x 3 columns]

# %%
df_keypoints_test
# Out:
#    key_point_id                                          key_point  \
# 0        kp_0_0  Routine child vaccinations, or their side effe...
# 1        kp_0_1     Mandatory vaccination contradicts basic rights
# 2        kp_0_2        The parents and not the state should decide
# 3        kp_0_3  Routine child vaccinations are not necessary t...
# 4        kp_0_4           Routine child vaccinations are effective
# 5        kp_0_5                      Child vaccination saves lives
# 6        kp_0_6  Routine child vaccinations are necessary to pr...
# 7        kp_0_7  Routine child vaccinations should be mandatory...
# 8        kp_0_8  Children should not suffer from preventable di...
# 9        kp_1_0           Social media regulation is not effective
# 10       kp_1_1              Social media regulation harms privacy
# 11       kp_1_2  Social media regulation harm freedom of speech...
# 12       kp_1_3  The government should not intervene in the aff...
# 13       kp_1_4  Social media regulation can lead to political ...
# 14       kp_1_5  Social media regulation protects the younger a...
# 15       kp_1_6  Social media regulation is necessary to deal w...
# 16       kp_1_7  Social media regulation is beneficial to socie...
# 17       kp_1_8  Social media regulation can help to deal with ...
# 18       kp_1_9  Social media regulation is required to deal wi...
# 19       kp_2_0    The US has unfair health and education policies
# 20       kp_2_1  The US has a problematic/divisive political sy...
# 21       kp_2_2      The US has high taxation/high costs of living
# 22       kp_2_3                        The US is xenophobic/racist
# 23       kp_2_4                      The US has inequality/poverty
# 24       kp_2_5                                   The US is unsafe
# 25       kp_2_6                      The US has a negative culture
# 26       kp_2_7  The US offers great opportunities for individuals
# 27       kp_2_8             The US has freedoms/ democratic rights
# 28       kp_2_9              The US has a great environment/nature
# 29      kp_2_10                       The US is a powerful country
# 30      kp_2_11  The US has a good economy/high standard of living
# 31      kp_2_12    The US has a good health and education systems
# 32      kp_2_13                    The US has great people/culture
#
#                                                 topic  stance
# 0      Routine child vaccinations should be mandatory      -1
# 1      Routine child vaccinations should be mandatory      -1
# 2      Routine child vaccinations should be mandatory      -1
# 3      Routine child vaccinations should be mandatory      -1
# 4      Routine child vaccinations should be mandatory       1
# 5      Routine child vaccinations should be mandatory       1
# 6      Routine child vaccinations should be mandatory       1
# 7      Routine child vaccinations should be mandatory       1
# 8      Routine child vaccinations should be mandatory       1
# 9   Social media platforms should be regulated by ...      -1
# 10  Social media platforms should be regulated by ...      -1
# 11  Social media platforms should be regulated by ...      -1
# 12  Social media platforms should be regulated by ...      -1
# 13  Social media platforms should be regulated by ...      -1
# 14  Social media platforms should be regulated by ...       1
# 15  Social media platforms should be regulated by ...       1
# 16  Social media platforms should be regulated by ...       1
# 17  Social media platforms should be regulated by ...       1
# 18  Social media platforms should be regulated by ...       1
# 19               The USA is a good country to live in      -1
# 20               The USA is a good country to live in      -1
# 21               The USA is a good country to live in      -1
# 22               The USA is a good country to live in      -1
# 23               The USA is a good country to live in      -1
# 24               The USA is a good country to live in      -1
# 25               The USA is a good country to live in      -1
# 26               The USA is a good country to live in       1
# 27               The USA is a good country to live in       1
# 28               The USA is a good country to live in       1
# 29               The USA is a good country to live in       1
# 30               The USA is a good country to live in       1
# 31               The USA is a good country to live in       1
# 32               The USA is a good country to live in       1

# %%
df_arguments_test
# Out:
#         arg_id                                           argument  \
# 0      arg_0_0  Routine child vaccinations isn't mandatory sin...
# 1      arg_0_1  Routine child vaccinations should not be manda...
# 2      arg_0_2  Routine child vaccinations should not be neces...
# 3      arg_0_3  A vaccine that has not been sufficiently teste...
# 4      arg_0_4  As long as vaccines are not free of side effec...
# ..         ...                                                ...
# 718  arg_2_205  usa is an excellent country to live with wonde...
# 719  arg_2_206  we all have the american dream. it is the best...
# 720  arg_2_207           yes for its economic and labor stability
# 721  arg_2_208  yes is the best country to live  to live the  ...
# 722  arg_2_209  yes, is a good country, beacause have good edu...
#
#                                               topic  stance
# 0    Routine child vaccinations should be mandatory      -1
# 1    Routine child vaccinations should be mandatory      -1
# 2    Routine child vaccinations should be mandatory      -1
# 3    Routine child vaccinations should be mandatory      -1
# 4    Routine child vaccinations should be mandatory      -1
# ..                                              ...     ...
# 718            The USA is a good country to live in       1
# 719            The USA is a good country to live in       1
# 720            The USA is a good country to live in       1
# 721            The USA is a good country to live in       1
# 722            The USA is a good country to live in       1
#
# [723 rows x 4 columns]

# %%
merged_dataset_test=df_labels.merge(df_arguments_test, left_on="arg_id", right_on="arg_id")
# df_arguments.loc[df_arguments['arg_id'] == "arg_4_121"]
full_dataset_test=merged_dataset.merge(df_keypoints_test, left_on="key_point_id", right_on="key_point_id")
full_dataset_test
# Out:
#          arg_id key_point_id label  \
# 0     arg_0_210       kp_0_7     0
# 1     arg_0_177       kp_0_7     0
# 2     arg_0_150       kp_0_7     0
# 3     arg_0_179       kp_0_7     0
# 4     arg_0_220       kp_0_7     0
# ...         ...          ...   ...
# 1260   arg_0_94       kp_0_0     0
# 1261   arg_0_10       kp_0_0     1
# 1262  arg_0_118       kp_0_0     1
# 1263  arg_0_113       kp_0_0     0
# 1264   arg_0_19       kp_0_0     0
#
#                                                argument  \
# 0     many people do not have the mental capacity to...
# 1     assisted suicide should be a criminal offence ...
# 2     assisted suicide is murder of another and shou...
# 3     assisted suicide should be a criminal offence ...
# 4     people may easily be manipulated into being a ...
# ...                                                 ...
# 1260  people should have the right to decide how and...
# 1261  assisted suicide allows terminally ill people ...
# 1262  We don't allow our pets to suffer but because ...
# 1263  the right to die is a personal choice and ever...
# 1264  assisted suicide is a human right and would sp...
#
#                                             topic_x  stance_x  \
# 0     Assisted suicide should be a criminal offence         1
# 1     Assisted suicide should be a criminal offence         1
# 2     Assisted suicide should be a criminal offence         1
# 3     Assisted suicide should be a criminal offence         1
# 4     Assisted suicide should be a criminal offence         1
# ...                                             ...       ...
# 1260  Assisted suicide should be a criminal offence        -1
# 1261  Assisted suicide should be a criminal offence        -1
# 1262  Assisted suicide should be a criminal offence        -1
# 1263  Assisted suicide should be a criminal offence        -1
# 1264  Assisted suicide should be a criminal offence        -1
#
#                                               key_point  \
# 0     Routine child vaccinations should be mandatory...
# 1     Routine child vaccinations should be mandatory...
# 2     Routine child vaccinations should be mandatory...
# 3     Routine child vaccinations should be mandatory...
# 4     Routine child vaccinations should be mandatory...
# ...                                                 ...
# 1260  Routine child vaccinations, or their side effe...
# 1261  Routine child vaccinations, or their side effe...
# 1262  Routine child vaccinations, or their side effe...
# 1263  Routine child vaccinations, or their side effe...
# 1264  Routine child vaccinations, or their side effe...
#
#                                              topic_y  stance_y
# 0     Routine child vaccinations should be mandatory         1
# 1     Routine child vaccinations should be mandatory         1
# 2     Routine child vaccinations should be mandatory         1
# 3     Routine child vaccinations should be mandatory         1
# 4     Routine child vaccinations should be mandatory         1
# ...                                              ...       ...
# 1260  Routine child vaccinations should be mandatory        -1
# 1261  Routine child vaccinations should be mandatory        -1
# 1262  Routine child vaccinations should be mandatory        -1
# 1263  Routine child vaccinations should be mandatory        -1
# 1264  Routine child vaccinations should be mandatory        -1
#
# [1265 rows x 9 columns]

# %%
altdata_arguments_test = sbert_model.encode(full_dataset_test["argument"])
# altdata_arguments
altdata_keypoints_test = sbert_model.encode(full_dataset_test["key_point"])
# altdata_keypoints
training_test = np.hstack((altdata_arguments_test, altdata_keypoints_test))
training_test
# Out:
# array([[ 0.22633937,  0.554146  ,  0.19942318, ..., -0.16148338,
#         -1.4278635 ,  0.53885126],
#        [-0.04930202,  0.10250104, -0.18276763, ..., -0.16148338,
#         -1.4278635 ,  0.53885126],
#        [-0.12522715,  0.03689397, -0.09041947, ..., -0.16148338,
#         -1.4278635 ,  0.53885126],
#        ...,
#        [ 0.15880401,  0.722718  ,  0.44542477, ..., -0.5389258 ,
#         -1.2187271 ,  0.33487737],
#        [ 0.05034905,  0.30275172,  0.89811814, ..., -0.5389258 ,
#         -1.2187271 ,  0.33487737],
#        [-0.54348224,  0.70539004,  0.6901144 , ..., -0.5389258 ,
#         -1.2187271 ,  0.33487737]], dtype=float32)

# %%
labels_test = np.array(full_dataset_test["label"])

# %%
pred = model.predict(training_test)
pred
# Out:
# array([[0.6208413 ],
#        [0.7763232 ],
#        [0.78500783],
#        ...,
#        [0.80521667],
#        [0.6045477 ],
#        [0.73299015]], dtype=float32)

# %%
pred = pred.flatten()

res = np.vstack((pred, labels_test))
df_res = pd.DataFrame(res)
df_res = df_res.transpose()
df_res.columns = ["predicted", "true"]
df_res['predicted_label'] = np.where(df_res['predicted'] >= 0.5, 1, 0)
df_res['match'] = np.where(df_res['true'] == df_res['predicted_label'], 1, 0)
print(df_res)
accuracy = df_res['match'].sum() / df_res.shape[0]
accuracy
# Out:
#      predicted true  predicted_label  match
# 0     0.620841    0                1      0
# 1     0.776323    0                1      0
# 2     0.785008    0                1      0
# 3     0.716067    0                1      0
# 4     0.701616    0                1      0
# ...        ...  ...              ...    ...
# 1260  0.780409    0                1      0
# 1261  0.768643    1                1      1
# 1262  0.805217    1                1      1
# 1263  0.604548    0                1      0
# 1264   0.73299    0                1      0
#
# [1265 rows x 4 columns]
# 0.5399209486166008

# %%
import sklearn as skl

# %%
df_res["true"]
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1260    0
# 1261    1
# 1262    1
# 1263    0
# 1264    0
# Name: true, Length: 1265, dtype: object

# %%
skl.metrics.f1_score(np.asarray(df_res["true"]).astype(float), np.asarray(df_res["predicted_label"]).astype(float))
# Out:
# 0.5174129353233831

# %%
df_res
# Out:
#      predicted true  predicted_label  match
# 0     0.620841    0                1      0
# 1     0.776323    0                1      0
# 2     0.785008    0                1      0
# 3     0.716067    0                1      0
# 4     0.701616    0                1      0
# ...        ...  ...              ...    ...
# 1260  0.780409    0                1      0
# 1261  0.768643    1                1      1
# 1262  0.805217    1                1      1
# 1263  0.604548    0                1      0
# 1264   0.73299    0                1      0
#
# [1265 rows x 4 columns]

# %%
df_res.describe()
# Out:
#        predicted_label        match
# count      1265.000000  1265.000000
# mean          0.457708     0.539921
# std           0.498405     0.498601
# min           0.000000     0.000000
# 25%           0.000000     0.000000
# 50%           0.000000     1.000000
# 75%           1.000000     1.000000
# max           1.000000     1.000000

# %%
df_one = df_res[df_res["true"] == 1]
df_one.describe()
# Out:
#        predicted_label       match
# count       627.000000  627.000000
# mean          0.497608    0.497608
# std           0.500393    0.500393
# min           0.000000    0.000000
# 25%           0.000000    0.000000
# 50%           0.000000    0.000000
# 75%           1.000000    1.000000
# max           1.000000    1.000000

# %%
df_zeros = df_res[df_res["true"] == 0]
df_zeros.describe()
# Out:
#        predicted_label       match
# count       638.000000  638.000000
# mean          0.418495    0.581505
# std           0.493699    0.493699
# min           0.000000    0.000000
# 25%           0.000000    0.000000
# 50%           0.000000    1.000000
# 75%           1.000000    1.000000
# max           1.000000    1.000000
